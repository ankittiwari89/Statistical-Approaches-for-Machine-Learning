# %%
Data=[2,5,5,5,6,6,7]

Given is the dataset as a list of integers where some integers are repeated
For each iteration in for loop print the number of times aecyh integer is seen and store this information in k:v format

# %%
data=[2,5,5,5,6,6,7]
freq={} # Empty dictionary
for x in data:
    freq[x]=freq.get(x,0)+1
    print(freq)
# Out:
# {2: 1}
# {2: 1, 5: 1}
# {2: 1, 5: 2}
# {2: 1, 5: 3}
# {2: 1, 5: 3, 6: 1}
# {2: 1, 5: 3, 6: 2}
# {2: 1, 5: 3, 6: 2, 7: 1}

# %%
data=[12,12,15,15,15,17,17,17,17,6,5,3,]
freq={}
for x in data:
    freq[x]=freq.get(x,0)+1
    print(freq)
# Out:
# {12: 1}
# {12: 2}
# {12: 2, 15: 1}
# {12: 2, 15: 2}
# {12: 2, 15: 3}
# {12: 2, 15: 3, 17: 1}
# {12: 2, 15: 3, 17: 2}
# {12: 2, 15: 3, 17: 3}
# {12: 2, 15: 3, 17: 4}
# {12: 2, 15: 3, 17: 4, 6: 1}
# {12: 2, 15: 3, 17: 4, 6: 1, 5: 1}
# {12: 2, 15: 3, 17: 4, 6: 1, 5: 1, 3: 1}

# %%
max_freq=max(freq.values())
print(max_freq)
# Out:
# 4

# %%
data=[12,15,15,15,25,25,36,36,36,36,47,57,57]
freq={}
for x in data:
   freq[x]=freq.get(x,0)+1
   print(freq)
max_freq=max(freq.values())
print(max_freq)
# Out:
# {12: 1}
# {12: 1, 15: 1}
# {12: 1, 15: 2}
# {12: 1, 15: 3}
# {12: 1, 15: 3, 25: 1}
# {12: 1, 15: 3, 25: 2}
# {12: 1, 15: 3, 25: 2, 36: 1}
# {12: 1, 15: 3, 25: 2, 36: 2}
# {12: 1, 15: 3, 25: 2, 36: 3}
# {12: 1, 15: 3, 25: 2, 36: 4}
# {12: 1, 15: 3, 25: 2, 36: 4, 47: 1}
# {12: 1, 15: 3, 25: 2, 36: 4, 47: 1, 57: 1}
# {12: 1, 15: 3, 25: 2, 36: 4, 47: 1, 57: 2}
# 4

# %%
data=[1,2,2,3,3,4]
freq={}
for x in data:
    freq[x]=freq.get(x,0)+1
    print(freq)
max_freq=max(freq.values())
print(max_freq)
# Out:
# {1: 1}
# {1: 1, 2: 1}
# {1: 1, 2: 2}
# {1: 1, 2: 2, 3: 1}
# {1: 1, 2: 2, 3: 2}
# {1: 1, 2: 2, 3: 2, 4: 1}
# 2

# %%
data=[1,2,2,3,3,3,4,4,4,4]
freq={}
for x in data:
    freq[x]=freq.get(x,0)+1
    print(freq)
max_freq=max(freq.values())
print(max_freq)
# Out:
# {1: 1}
# {1: 1, 2: 1}
# {1: 1, 2: 2}
# {1: 1, 2: 2, 3: 1}
# {1: 1, 2: 2, 3: 2}
# {1: 1, 2: 2, 3: 3}
# {1: 1, 2: 2, 3: 3, 4: 1}
# {1: 1, 2: 2, 3: 3, 4: 2}
# {1: 1, 2: 2, 3: 3, 4: 3}
# {1: 1, 2: 2, 3: 3, 4: 4}
# 4
