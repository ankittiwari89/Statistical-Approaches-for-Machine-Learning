# %%
k=[2,4,5,6,8,9,12,14,15,17,19]

print(k[0])
print(k[1])
print(k[2])
print(k[3])
print(k[4])
print(k[5])
print(k[6])
print(k[7])
print(k[8])
print(k[9])
print(k[10])
# Out:
# 2
# 4
# 5
# 6
# 8
# 9
# 12
# 14
# 15
# 17
# 19

# %%
k=[2,4,5,6,8,9,12,14,15,17,19]
n=len(k)
mid_pos=n//2
print("mid_pos:",mid_pos)
# Out:
# mid_pos: 5

# %%
print

# %%
k=[12,14,15,16,18,19,22,24,25,27,29,39,40,42,45,47,49]
n=len(k)
mid_pos=n//2
print(mid_pos)
print(k[mid_pos])
# Out:
# 8
# 25

# %%
m=[12,14,15]
n=len(m)
mid_pos=n//2
print(mid_pos)
print(m[mid_pos])
# Out:
# 1
# 14

# %%
N=[12,14,15,16,17]
z=len(N)
mid_pos=z//2
print(mid_pos)
print(N[mid_pos])
# Out:
# 2
# 15

# %%
#A
Q=[12,14,15,16,18,19]
#print the value of Q[0]
#print the index of mid position of the list 
# print the value at index of mid position of this list

print(Q[0:])
#B
n=len(Q)
midpos1=n//2-1
midpos2=n//2
print(midpos1,midpos2)

#C
print(Q[midpos1],Q[midpos2])
# Out:
# [12, 14, 15, 16, 18, 19]
# 2 3
# 15 16

# %%
S=[12,14,15,16,18,19,20,22,24,27]
n=len(S)
midpos1=n//2-1
midpos2=n//2
print(midpos1,midpos2)
print(S[midpos1],S[midpos2])
# Out:
# 4 5
# 18 19

# %%
R=[12,14,15,16,18,19,20,22]
n=len(R)
print(R[0:])
midpos1=n//2-1
midpos2=n//2
print(midpos1,midpos2)
print(R[midpos1],R[midpos2])
# Out:
# [12, 14, 15, 16, 18, 19, 20, 22]
# 3 4
# 16 18
